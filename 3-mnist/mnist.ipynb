# %% [markdown]
# # MNIST回路テスト(Interface 2017.8より)

# %% [markdown]
# ## DNN版

# %% [markdown]
# ### トレーニング実行＆モデルデータ生成

# %%
# %run -i train_mnist_dnn.py -g 0 -o result/dnn
# Out:
# GPU: 0
# # unit: 1000
# # Minibatch-size: 100
# # epoch: 20
#
# epoch       main/loss   validation/main/loss  main/accuracy  validation/main/accuracy  elapsed_time
#      total [..................................................]  0.83%
# this epoch [########..........................................] 16.67%
#        100 iter, 0 epoch / 20 epochs
#        inf iters/sec. Estimated time to finish: 0:00:00.
#      total [..................................................]  1.67%
# this epoch [################..................................] 33.33%
#        200 iter, 0 epoch / 20 epochs
#     208.29 iters/sec. Estimated time to finish: 0:00:56.652972.
#      total [#.................................................]  2.50%
# this epoch [#########################.........................] 50.00%
#        300 iter, 0 epoch / 20 epochs
#     208.77 iters/sec. Estimated time to finish: 0:00:56.041239.
#      total [#.................................................]  3.33%
# ...

# %% [markdown]
# ### 評価

# %%
# %run -i eval_myimage_dnn.py -i tegaki/tegaki1.png -m result/dnn/MLP.model
# Out:
# 自分の手書き文字を学習したモデルで評価してみるプログラム
# # 入力画像ファイル: tegaki/tegaki1.png
# # 学習済みモデルファイル: result/dnn/MLP.model
#
# 判定結果は1です。

# %% [markdown]
# ### ネットワーク構造及び正当率/誤差グラフ表示

# %%
# !dot -Tpng result/dnn/cg.dot -o result/dnn/cg.png

from IPython.display import Image
from IPython.display import display

display(Image(filename='result/dnn/cg.png'))
display(Image(filename='result/dnn/accuracy.png'))
display(Image(filename='result/dnn/loss.png'))

# %% [markdown]
# ## CNN版

# %% [markdown]
# ### トレーニング実行＆モデルデータ生成

# %%
# %run -i train_mnist_cnn.py -g 0 -o result/cnn
# Out:
# GPU: 0
# # unit: 1000
# # Minibatch-size: 100
# # epoch: 20
#
# epoch       main/loss   validation/main/loss  main/accuracy  validation/main/accuracy  elapsed_time
#      total [..................................................]  0.83%
# this epoch [########..........................................] 16.67%
#        100 iter, 0 epoch / 20 epochs
#        inf iters/sec. Estimated time to finish: 0:00:00.
#      total [..................................................]  1.67%
# this epoch [################..................................] 33.33%
#        200 iter, 0 epoch / 20 epochs
#     173.12 iters/sec. Estimated time to finish: 0:01:08.159557.
#      total [#.................................................]  2.50%
# this epoch [#########################.........................] 50.00%
#        300 iter, 0 epoch / 20 epochs
#     179.27 iters/sec. Estimated time to finish: 0:01:05.265242.
#      total [#.................................................]  3.33%
# ...

# %% [markdown]
# ### 評価

# %%
# %run -i eval_myimage_cnn.py -i tegaki/tegaki1.png -m result/cnn/MLP.model
# Out:
# 自分の手書き文字を学習したモデルで評価してみるプログラム
# # 入力画像ファイル: tegaki/tegaki1.png
# # 学習済みモデルファイル: result/cnn/MLP.model
#
# 判定結果は1です。

# %% [markdown]
# ### ネットワーク構造及び正当率/誤差グラフ表示

# %%
# !dot -Tpng result/cnn/cg.dot -o result/cnn/cg.png

from IPython.display import Image
from IPython.display import display

display(Image(filename='result/cnn/cg.png'))
display(Image(filename='result/cnn/accuracy.png'))
display(Image(filename='result/cnn/loss.png'))
