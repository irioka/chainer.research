# %% [markdown]
# # Interface 2017.8

# %% [markdown]
# ## MNIST回路テスト

# %% [markdown]
# ### トレーニング実行＆モデルデータ生成

# %%
# %run -i train_mnist_dnn.py -g 0
# Out:
# GPU: 0
# # unit: 1000
# # Minibatch-size: 100
# # epoch: 20
#
# epoch       main/loss   validation/main/loss  main/accuracy  validation/main/accuracy  elapsed_time
#      total [..................................................]  0.83%
# this epoch [########..........................................] 16.67%
#        100 iter, 0 epoch / 20 epochs
#        inf iters/sec. Estimated time to finish: 0:00:00.
#      total [..................................................]  1.67%
# this epoch [################..................................] 33.33%
#        200 iter, 0 epoch / 20 epochs
#     213.26 iters/sec. Estimated time to finish: 0:00:55.332447.
#      total [#.................................................]  2.50%
# this epoch [#########################.........................] 50.00%
#        300 iter, 0 epoch / 20 epochs
#     208.86 iters/sec. Estimated time to finish: 0:00:56.017361.
#      total [#.................................................]  3.33%
# ...

# %% [markdown]
# ### 評価

# %%
# %run -i eval_myimage_dnn.py -i tegaki/tegaki1.png -m result/MLP.model
# Out:
# 自分の手書き文字を学習したモデルで評価してみるプログラム
# # 入力画像ファイル: tegaki/tegaki1.png
# # 学習済みモデルファイル: result/MLP.model
#
# 判定結果は1です。

# %% [markdown]
# ### ネットワーク構造及び正当率/誤差グラフ表示

# %%
# !dot -Tpng result/cg.dot -o result/cg.png

from IPython.display import Image
from IPython.display import display

display(Image(filename='result/cg.png'))
display(Image(filename='result/accuracy.png'))
display(Image(filename='result/loss.png'))
